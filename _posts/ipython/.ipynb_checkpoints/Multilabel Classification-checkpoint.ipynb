# %% [markdown]
# ## Multilabel Classification with scikit-multilearn
#
# ### 1. Introduction
#
# We typically group supervised machine learning problems into classification and regression problems. Within the classification problems sometimes, multiclass classification models are encountered where the classification is not binary but we have to assign a class from `n` choices.
#
# In multilabel classification, instead of one target variable $y$, we have multiple target variables $y_1$, $y_2$, ..., $y_n$. For example there can be multiple objects in an image and we need to correctly classify them all or we are attempting predict which combination of a product that a customer would buy.
#
# Certain decision tree based algorithms in [Scikit-Learn](http://scikit-learn.org/stable/modules/multiclass.html) are naturally able to handle multilabel classification. [scikit-multilearn](http://scikit.ml/) leverages Scikit-Learn and is built specifically for multilabel problems.

# %% [markdown]
# ### 2. Datasets
#
# We use the AmazonCat-13K dataset to explore different multilabel algorithms available in Scikit-Multilearn. Our goal is not to optimize classifier performance but to explore the various algorithms applicable to multilabel classification problems. The dataset if fairly large with over 1.1M train points and 300k test points. There are over 200k features and 13k labels.
#
# This dataset was chosen in order to work with a fairly large dataset to illustrate difficulties in multilabel classification instead of a toy example. In particular when there are $N$ labels, the search space increases exponentially to $2^N$. A list of multilabel datasets can be found at Manik Varma's [Extreme Classification Repository](http://manikvarma.org/downloads/XC/XMLRepository.html). The data is provided in sparse format and the authors only provide Matlab scripts to convert them; some data wrangling is needed in python to handle them.

# %%
from scipy import sparse
import gc

#f = open(r'C:\Users\david\Downloads\RCV1-x\rcv1x_train.txt', 'r',encoding='utf-8')
f = open(r'C:\Users\kaoyuant\Downloads\RCV1-x\rcv1x_train.txt', 'r',encoding='utf-8')

    
    
size = f.readline()
nrows, nfeature,nlabel = [int(s) for s in size.split()]
x_m = [[] for i in range(nrows)]
pos = [[] for i in range(nrows)]
y_m = [[] for i in range(nrows)]

for i in range(nrows):
    line = f.readline()
    temp=[s for s in line.split(sep=' ')]
    pos[i]=[int(s.split(':')[0]) for s in temp[1:]]
    x_m[i]=[float(s.split(':')[1]) for s in temp[1:]]
    for s in temp[0].split(','):
        try:
            int(s)
            y_m[i]=[ int(s) for s in temp[0].split(',')]
        except:
            y_m[i]=[]
          
x_train=sparse.lil_matrix((nrows,nfeature))
for i in range(nrows):
    for j in range(len(pos[i])):
        x_train[i,pos[i][j]]=x_m[i][j]

del x_m,pos
gc.collect()

y_train=sparse.lil_matrix((nrows,nlabel))
for i in range(nrows):
    for j in y_m[i]:
        y_train[i,j]=1

del y_m
gc.collect()
# Out:
# 0

# %%
prod = [(x, y) for x in range(nrows) for y in pos] # combinations
r = [x for (x, y) in prod] # x_coordinate
c = [y for (x, y) in prod] # y_coordinate
data = [1] * len(r)
m = scipy.sparse.coo_matrix((data, (r, c)), shape=(nrows, nfeature))

# %%
#f = open(r'C:\Users\david\Downloads\RCV1-x\rcv1x_test.txt', 'r',encoding='utf-8')
f = open(r'C:\Users\kaoyuant\Downloads\RCV1-x\rcv1x_test.txt', 'r',encoding='utf-8')

size = f.readline()
nrows, nfeature,nlabel = [int(s) for s in size.split()]
x_m = [[] for i in range(nrows)]
pos = [[] for i in range(nrows)]
y_m = [[] for i in range(nrows)]

for i in range(nrows):
    line = f.readline()
    temp=[s for s in line.split(sep=' ')]
    pos[i]=[int(s.split(':')[0]) for s in temp[1:]]
    x_m[i]=[float(s.split(':')[1]) for s in temp[1:]]
    for s in temp[0].split(','):
        try:
            int(s)
            y_m[i]=[ int(s) for s in temp[0].split(',')]
        except:
            y_m[i]=[]
          

x_test=sparse.lil_matrix((nrows,nfeature))
for i in range(nrows):
    for j in range(len(pos[i])):
        x_test[i,pos[i][j]]=x_m[i][j]

del x_m,pos
gc.collect()

y_test=sparse.lil_matrix((nrows,nlabel))
for i in range(nrows):
    for j in y_m[i]:
        y_test[i,j]=1

del y_m
gc.collect()

# %% [markdown]
# ### 3. Metric
#
# Before going into the details of each multilabel classification method, we select a metric to gauge how well the algorithm is performing. Similar to a classification problem it is possible to use `Hamming Loss`, `Accuracy`, `Precision`, `Jaccard Similarity`, `Recall`, and `F1 Score`. These are available from Scikit-Learn.
#
# Going forward we'll chose the `F1 Score` as it averages both `Precision` and `Recall`. It is also helpful to plot the confusion matrix to understand how the classifier is performing, but in our case there are too many labels to visualize.

# %%
Image of confusion matrix
# Out:
#   File "<ipython-input-6-853b10b3eedc>", line 1
#     Image of confusion matrix
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 3. Problem Transformation
#
# #### Binary Relevance
#
# Binary relevance is simple; each target variable ($y_1$, $y_2$,..,$y_n$) is treated independently and we are reduced to $n$ classification problems. `Scikit-Multilearn` implements this for us, saving us the hassle of splitting the dataset and training each of them separately.

# %%
from skmultilearn.problem_transform import BinaryRelevance
from sklearn.ensemble import RandomForestClassifier
import time

classifier = BinaryRelevance(
    classifier = RandomForestClassifier(),
    require_dense = [False, True]
)

start=time.time()
classifier.fit(x_train, y_train)
y_hat = classifier.predict(x_test)
print(time.time()-start)

# %%
import sklearn.metrics as metrics

metrics.f1_score(y_test, y_hat)

# %% [markdown]
# #### Label Powerset
#
# This method transforms the problem into a multiclass classification problem; the target variables ($y_1$, $y_2$,..,$y_n$) are combined and each combination is treated as a unique class. This method will produce many classes.

# %%
from skmultilearn.problem_transform import LabelPowerset

classifier = ClassifierChain(
    classifier = RandomForestClassifier(),
    require_dense = [False, True]
)

start=time.time()
classifier.fit(x_train, y_train)
y_hat = classifier.predict(x_test)
print(time.time()-start)

# %%
metrics.f1_score(y_test, y_hat)

# %% [markdown]
# #### Classifier Chains
#
# Classifier chains are akin to binary relevance, however the target variables ($y_1$, $y_2$,..,$y_n$) are not fully independent.

# %%
from skmultilearn.problem_transform import ClassifierChain

classifier = ClassifierChain(
    classifier = RandomForestClassifier,
    require_dense = [False, True]
)

start=time.time()
classifier.fit(x_train, y_train)
y_hat = classifier.predict(x_test)
print(time.time()-start)

# %%
metrics.f1_score(y_test, y_hat)

# %% [markdown]
# ### FastXML

# %%
import os
os.chdir(r'C:\Users\kaoyuant\github\fastxml\fastxml')
import pyximport
pyximport.install()
from fastxml import Trainer, Inferencer
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# <ipython-input-18-8b02911fd0fc> in <module>()
#       3 import pyximport
#       4 pyximport.install()
# ----> 5 from fastxml import Trainer, Inferencer
#
# C:\Users\kaoyuant\github\fastxml\fastxml\fastxml.py in <module>()
#       7 import scipy.sparse as sp
#       8
# ----> 9 from .inferencer import IForest, LeafComputer, Blender, IForestBlender
#      10
#      11 class Inferencer(object):
#
# SystemError: Parent module '' not loaded, cannot perform relative import

# %%
import inferencer
# Out:
# warning: C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Includes\libcpp\algorithm.pxd:7:40: Function signature does not match previous declaration
# warning: C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Includes\libcpp\algorithm.pxd:11:38: Function signature does not match previous declaration
# warning: C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Includes\libcpp\algorithm.pxd:15:38: Function signature does not match previous declaration
# warning: C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Includes\libcpp\algorithm.pxd:19:36: Function signature does not match previous declaration
# warning: C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Includes\libcpp\algorithm.pxd:23:28: Function signature does not match previous declaration
# warning: C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Includes\libcpp\algorithm.pxd:27:38: Function signature does not match previous declaration
# warning: C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Includes\libcpp\algorithm.pxd:31:33: Function signature does not match previous declaration
# warning: C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Includes\libcpp\algorithm.pxd:34:32: Function signature does not match previous declaration
# warning: C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Includes\libcpp\algorithm.pxd:37:33: Function signature does not match previous declaration
# warning: C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Includes\libcpp\algorithm.pxd:40:33: Function signature does not match previous declaration
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# from .utility cimport pair
#
# cdef extern from "<unordered_map>" namespace "std" nogil:
#     cdef cppclass unordered_map[T, U]:
#         ctypedef T key_type
#        ^
# ------------------------------------------------------------
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Includes\libcpp\unordered_map.pxd:5:8: Expected an identifier, found 'ctypedef'
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# from .utility cimport pair
#
# cdef extern from "<unordered_map>" namespace "std" nogil:
#     cdef cppclass unordered_map[T, U]:
#         ctypedef T key_type
#                   ^
# ------------------------------------------------------------
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Includes\libcpp\unordered_map.pxd:5:19: Syntax error in C variable declaration
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# cimport numpy as np
#
# from libc.math cimport log, abs, exp, pow
# from cython.operator cimport dereference as deref, preincrement as inc
# from libcpp.algorithm cimport sort as stdsort
# from libcpp.unordered_map cimport unordered_map
# ^
# ------------------------------------------------------------
#
# inferencer.pyx:13:0: 'libcpp\unordered_map\unordered_map.pxd' not found
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# cdef extern from "<vector>" namespace "std" nogil:
#     cdef cppclass vector[T,ALLOCATOR=*]:
#         ctypedef T value_type
#        ^
# ------------------------------------------------------------
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Includes\libcpp\vector.pxd:3:8: Expected an identifier, found 'ctypedef'
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# cdef extern from "<vector>" namespace "std" nogil:
#     cdef cppclass vector[T,ALLOCATOR=*]:
#         ctypedef T value_type
#                   ^
# ------------------------------------------------------------
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Includes\libcpp\vector.pxd:3:19: Syntax error in C variable declaration
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# from libc.math cimport log, abs, exp, pow
# from cython.operator cimport dereference as deref, preincrement as inc
# from libcpp.algorithm cimport sort as stdsort
# from libcpp.unordered_map cimport unordered_map
# from libcpp cimport bool
# from libcpp.vector cimport vector
# ^
# ------------------------------------------------------------
#
# inferencer.pyx:15:0: 'libcpp\vector\vector.pxd' not found
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# cdef extern from "<utility>" namespace "std" nogil:
#     cdef cppclass pair[T, U]:
#         ctypedef T first_type
#        ^
# ------------------------------------------------------------
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Includes\libcpp\utility.pxd:3:8: Expected an identifier, found 'ctypedef'
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# cdef extern from "<utility>" namespace "std" nogil:
#     cdef cppclass pair[T, U]:
#         ctypedef T first_type
#                   ^
# ------------------------------------------------------------
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Includes\libcpp\utility.pxd:3:19: Syntax error in C variable declaration
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# from .utility cimport pair
# ^
# ------------------------------------------------------------
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Includes\libcpp\pair.pxd:1:0: 'libcpp\utility\pair.pxd' not found
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# from libcpp.unordered_map cimport unordered_map
# from libcpp cimport bool
# from libcpp.vector cimport vector
# from libcpp.pair cimport pair
#
# ctypedef pair[int,float] DP
#         ^
# ------------------------------------------------------------
#
# inferencer.pyx:18:9: 'pair' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# from libcpp cimport bool
# from libcpp.vector cimport vector
# from libcpp.pair cimport pair
#
# ctypedef pair[int,float] DP
# ctypedef vector[DP] SR
#         ^
# ------------------------------------------------------------
#
# inferencer.pyx:19:9: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# from libcpp.vector cimport vector
# from libcpp.pair cimport pair
#
# ctypedef pair[int,float] DP
# ctypedef vector[DP] SR
# ctypedef vector[SR] CSR
#         ^
# ------------------------------------------------------------
#
# inferencer.pyx:20:9: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# from libcpp.pair cimport pair
#
# ctypedef pair[int,float] DP
# ctypedef vector[DP] SR
# ctypedef vector[SR] CSR
# ctypedef vector[vector[float]] DENSE
#         ^
# ------------------------------------------------------------
#
# inferencer.pyx:21:9: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         p.second = data[i]
#         sparse.push_back(p)
#
#     return sparse
#
# cdef SR sparse_sr_mean(const vector[SR*] probs, SR& averaged):
#                             ^
# ------------------------------------------------------------
#
# inferencer.pyx:80:29: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#             for i in range(0, len(values)):
#                 row.push_back(values[i])
#
#             dense.push_back(row)
#
# cdef load_dense_int(str fname, vector[vector[int]]& dense):
#                               ^
# ------------------------------------------------------------
#
# inferencer.pyx:152:31: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         self._predict(sr, payload)
#         return sr_to_sparse(payload, self.n_labels)
#
# cdef class ITree:
#     cdef int rootIdx
#     cdef vector[vector[int]] tree
#         ^
# ------------------------------------------------------------
#
# inferencer.pyx:274:9: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     cdef vector[vector[int]] tree
#     cdef CSR payloads
#
#     cdef CSR W
#
#     cdef vector[float] bias
#         ^
# ------------------------------------------------------------
#
# inferencer.pyx:279:9: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
#     cdef SR* predict_payload(self, const SR& sr):
#         cdef int idx = self.predict_sr(sr)
#         return &self.payloads[idx]
#
#     cdef inline int index(self, const vector[int]& node):
#                                      ^
# ------------------------------------------------------------
#
# inferencer.pyx:305:38: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         return &self.payloads[idx]
#
#     cdef inline int index(self, const vector[int]& node):
#         return node[0]
#
#     cdef inline int left(self, const vector[int]& node):
#                                     ^
# ------------------------------------------------------------
#
# inferencer.pyx:308:37: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         return node[0]
#
#     cdef inline int left(self, const vector[int]& node):
#         return node[1]
#
#     cdef inline int right(self, const vector[int]& node):
#                                      ^
# ------------------------------------------------------------
#
# inferencer.pyx:311:38: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         return node[1]
#
#     cdef inline int right(self, const vector[int]& node):
#         return node[2]
#
#     cdef inline bool is_leaf(self, const vector[int]& node):
#                                         ^
# ------------------------------------------------------------
#
# inferencer.pyx:314:41: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#             node = self.tree[nIndex]
#
#         return self.index(node)
#
# cdef class LeafComputer:
#     cdef vector[float] norms
#         ^
# ------------------------------------------------------------
#
# inferencer.pyx:338:9: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
#         return self.index(node)
#
# cdef class LeafComputer:
#     cdef vector[float] norms
#     cdef vector[float] radii
#         ^
# ------------------------------------------------------------
#
# inferencer.pyx:339:9: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         self.radii.swap(tmp2[0])
#
#         # Load means
#         load_sparse(p + '.means', self.means)
#
#     cdef void predict(self, const SR& X, const vector[int] ys, const float gamma, SR& out):
#                                               ^
# ------------------------------------------------------------
#
# inferencer.pyx:358:47: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#             k = exp(gamma  * (dist - self.radii[yi]))
#             p.first = i
#             p.second = 1. / (1. + k)
#             out.push_back(p)
#
# cdef void norm(const vector[float]& norms, const SR& X, SR& normed):
#                     ^
# ------------------------------------------------------------
#
# inferencer.pyx:378:21: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     cdef np.ndarray[np.int32_t] c = np.zeros(count, dtype=np.int32)
#     cdef np.ndarray[np.float32_t] d = np.zeros(count, dtype=np.float32)
#
#     cdef int [:] cv = c
#     cdef float [:] dv = d
#     cdef pair[int,float] p
#         ^
# ------------------------------------------------------------
#
# inferencer.pyx:32:9: 'pair' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
#     return tally + bias
#
# cdef SR convert_to_sr(const int [:] indices, const float [:] data, const int size):
#     cdef SR sparse
#     cdef pair[int,float] p
#         ^
# ------------------------------------------------------------
#
# inferencer.pyx:69:9: 'pair' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         sparse.push_back(p)
#
#     return sparse
#
# cdef SR sparse_sr_mean(const vector[SR*] probs, SR& averaged):
#     cdef unordered_map[int,float] summer
#         ^
# ------------------------------------------------------------
#
# inferencer.pyx:81:9: 'unordered_map' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         sr = probs[i]
#         for k in range(deref(sr).size()):
#             summer[deref(sr)[k].first] += deref(sr)[k].second
#
#     # Copy it into a new vector, averaging the values
#     cdef unordered_map[int,float].iterator b = summer.begin()
#         ^
# ------------------------------------------------------------
#
# inferencer.pyx:92:9: 'unordered_map' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         for k in range(deref(sr).size()):
#             summer[deref(sr)[k].first] += deref(sr)[k].second
#
#     # Copy it into a new vector, averaging the values
#     cdef unordered_map[int,float].iterator b = summer.begin()
#     cdef unordered_map[int,float].iterator e = summer.end()
#         ^
# ------------------------------------------------------------
#
# inferencer.pyx:93:9: 'unordered_map' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#                 row.push_back(p)
#
#             csr.push_back(row)
#
# cdef load_dense_f32(str fname, DENSE& dense):
#     cdef vector[float] row
#         ^
# ------------------------------------------------------------
#
# inferencer.pyx:136:9: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#                 row.push_back(values[i])
#
#             dense.push_back(row)
#
# cdef load_dense_int(str fname, vector[vector[int]]& dense):
#     cdef vector[int] row
#         ^
# ------------------------------------------------------------
#
# inferencer.pyx:153:9: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         # If blend == 1.0, we're done
#         if blend == 1.0:
#             return sr_to_sparse(tree_probs, self.forest.n_labels)
#
#         cdef SR leaf_probs
#         cdef vector[int] labels
#             ^
# ------------------------------------------------------------
#
# inferencer.pyx:193:13: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
#     cdef SR* _predict_tree(self, const SR& sr, ITree t):
#         return t.predict_payload(sr)
#
#     cdef void _predict(self, const SR& sr, SR& payload):
#         cdef vector[SR*] prob_set
#             ^
# ------------------------------------------------------------
#
# inferencer.pyx:257:13: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     cdef inline bool is_leaf(self, const vector[int]& node):
#         return node[3] == 1
#
#     cdef int predict_sr(self, const SR& data):
#         cdef unsigned int index, nIndex
#         cdef vector[int] node
#             ^
# ------------------------------------------------------------
#
# inferencer.pyx:319:13: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         val = deref(b)
#         val.second = val.second / probs.size()
#         averaged.push_back(val)
#         inc(b)
#
#     stdsort(averaged.begin(), averaged.end())
#           ^
# ------------------------------------------------------------
#
# inferencer.pyx:102:11: Call with wrong number of arguments (expected 3, got 2)
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         while True:
#             values = read_row(f, 'If')
#             if values is None:
#                 break
#
#             row = vector[DP]()
#                           ^
# ------------------------------------------------------------
#
# inferencer.pyx:127:27: 'DP' is not a constant, variable or function identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     cdef void _predict(self, const SR& sr, SR& payload):
#         cdef vector[SR*] prob_set
#         cdef SR* res
#         for t in self.trees:
#             res = self._predict_tree(sr, t)
#             prob_set.push_back(res)
#                                  ^
# ------------------------------------------------------------
#
# inferencer.pyx:261:34: Cannot convert 'SR *' to Python object
# ---------------------------------------------------------------------------
# DistutilsExecError                        Traceback (most recent call last)
# C:\Users\kaoyuant\Anaconda3\lib\distutils\_msvccompiler.py in compile(self, sources, output_dir, macros, include_dirs, debug, extra_preargs, extra_postargs, depends)
#     383             try:
# --> 384                 self.spawn(args)
#     385             except DistutilsExecError as msg:
#
# C:\Users\kaoyuant\Anaconda3\lib\distutils\_msvccompiler.py in spawn(self, cmd)
#     502             os.environ['path'] = self._paths
# --> 503             return super().spawn(cmd)
#     504         finally:
#
# C:\Users\kaoyuant\Anaconda3\lib\distutils\ccompiler.py in spawn(self, cmd)
#     908     def spawn(self, cmd):
# --> 909         spawn(cmd, dry_run=self.dry_run)
#     910
#
# C:\Users\kaoyuant\Anaconda3\lib\distutils\spawn.py in spawn(cmd, search_path, verbose, dry_run)
#      37     elif os.name == 'nt':
# ---> 38         _spawn_nt(cmd, search_path, dry_run=dry_run)
#      39     else:
#
# C:\Users\kaoyuant\Anaconda3\lib\distutils\spawn.py in _spawn_nt(cmd, search_path, verbose, dry_run)
#      80             raise DistutilsExecError(
# ---> 81                   "command %r failed with exit status %d" % (cmd, rc))
#      82
#
# DistutilsExecError: command 'C:\\Program Files (x86)\\Microsoft Visual Studio 14.0\\VC\\BIN\\x86_amd64\\cl.exe' failed with exit status 2
#
# During handling of the above exception, another exception occurred:
#
# CompileError                              Traceback (most recent call last)
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\pyximport\pyximport.py in load_module(name, pyxfilename, pyxbuild_dir, is_package, build_inplace, language_level, so_path)
#     215                                    inplace=build_inplace, language_level=language_level)
# --> 216         mod = imp.load_dynamic(name, so_path)
#     217         if is_package and not hasattr(mod, '__path__'):
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\pyximport\pyximport.py in build_module(name, pyxfilename, pyxbuild_dir, inplace, language_level)
#     191                                   reload_support=pyxargs.reload_support)
# --> 192     assert os.path.exists(so_path), "Cannot find: %s" % so_path
#     193
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\pyximport\pyxbuild.py in pyx_to_dll(filename, ext, force_rebuild, build_in_temp, pyxbuild_dir, setup_args, reload_support, inplace)
#     101         obj_build_ext = dist.get_command_obj("build_ext")
# --> 102         dist.run_commands()
#     103         so_path = obj_build_ext.get_outputs()[0]
#
# C:\Users\kaoyuant\Anaconda3\lib\distutils\dist.py in run_commands(self)
#     954         for cmd in self.commands:
# --> 955             self.run_command(cmd)
#     956
#
# C:\Users\kaoyuant\Anaconda3\lib\distutils\dist.py in run_command(self, command)
#     973         cmd_obj.ensure_finalized()
# --> 974         cmd_obj.run()
#     975         self.have_run[command] = 1
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Distutils\build_ext.py in run(self)
#
# C:\Users\kaoyuant\Anaconda3\lib\distutils\command\build_ext.py in run(self)
#     337         # Now actually compile and link everything.
# --> 338         self.build_extensions()
#     339
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Distutils\build_ext.py in build_extensions(self)
#
# C:\Users\kaoyuant\Anaconda3\lib\distutils\command\build_ext.py in build_extension(self, ext)
#     531                                          extra_postargs=extra_args,
# --> 532                                          depends=ext.depends)
#     533
#
# C:\Users\kaoyuant\Anaconda3\lib\distutils\_msvccompiler.py in compile(self, sources, output_dir, macros, include_dirs, debug, extra_preargs, extra_postargs, depends)
#     385             except DistutilsExecError as msg:
# --> 386                 raise CompileError(msg)
#     387
#
# CompileError: command 'C:\\Program Files (x86)\\Microsoft Visual Studio 14.0\\VC\\BIN\\x86_amd64\\cl.exe' failed with exit status 2
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-16-ed4f1c82d079> in <module>()
# ----> 1 import inferencer
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\pyximport\pyximport.py in load_module(self, fullname)
#     443             "invalid module, expected %s, got %s" % (
#     444             self.fullname, fullname))
# --> 445         if self.init_path:
#     446             # package
#     447             #print "PACKAGE", fullname
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\pyximport\pyximport.py in load_module(name, pyxfilename, pyxbuild_dir, is_package, build_inplace, language_level, so_path)
#     230             if sys.version_info[0] >= 3:
#     231                 raise exc.with_traceback(tb)
# --> 232             else:
#     233                 exec("raise exc, None, tb", {'exc': exc, 'tb': tb})
#     234     return mod
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\pyximport\pyximport.py in load_module(name, pyxfilename, pyxbuild_dir, is_package, build_inplace, language_level, so_path)
#     214             so_path = build_module(module_name, pyxfilename, pyxbuild_dir,
#     215                                    inplace=build_inplace, language_level=language_level)
# --> 216         mod = imp.load_dynamic(name, so_path)
#     217         if is_package and not hasattr(mod, '__path__'):
#     218             mod.__path__ = [os.path.dirname(so_path)]
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\pyximport\pyximport.py in build_module(name, pyxfilename, pyxbuild_dir, inplace, language_level)
#     190                                   inplace=inplace,
#     191                                   reload_support=pyxargs.reload_support)
# --> 192     assert os.path.exists(so_path), "Cannot find: %s" % so_path
#     193
#     194     junkpath = os.path.join(os.path.dirname(so_path), name+"_*") #very dangerous with --inplace ? yes, indeed, trying to eat my files ;)
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\pyximport\pyxbuild.py in pyx_to_dll(filename, ext, force_rebuild, build_in_temp, pyxbuild_dir, setup_args, reload_support, inplace)
#     100     try:
#     101         obj_build_ext = dist.get_command_obj("build_ext")
# --> 102         dist.run_commands()
#     103         so_path = obj_build_ext.get_outputs()[0]
#     104         if obj_build_ext.inplace:
#
# C:\Users\kaoyuant\Anaconda3\lib\distutils\dist.py in run_commands(self)
#     953         """
#     954         for cmd in self.commands:
# --> 955             self.run_command(cmd)
#     956
#     957     # -- Methods that operate on its Commands --------------------------
#
# C:\Users\kaoyuant\Anaconda3\lib\distutils\dist.py in run_command(self, command)
#     972         cmd_obj = self.get_command_obj(command)
#     973         cmd_obj.ensure_finalized()
# --> 974         cmd_obj.run()
#     975         self.have_run[command] = 1
#     976
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Distutils\build_ext.py in run(self)
#
# C:\Users\kaoyuant\Anaconda3\lib\distutils\command\build_ext.py in run(self)
#     336
#     337         # Now actually compile and link everything.
# --> 338         self.build_extensions()
#     339
#     340     def check_extensions_list(self, extensions):
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Distutils\build_ext.py in build_extensions(self)
#
# C:\Users\kaoyuant\Anaconda3\lib\distutils\command\build_ext.py in build_extension(self, ext)
#     530                                          debug=self.debug,
#     531                                          extra_postargs=extra_args,
# --> 532                                          depends=ext.depends)
#     533
#     534         # XXX outdated variable, kept here in case third-part code
#
# C:\Users\kaoyuant\Anaconda3\lib\distutils\_msvccompiler.py in compile(self, sources, output_dir, macros, include_dirs, debug, extra_preargs, extra_postargs, depends)
#     384                 self.spawn(args)
#     385             except DistutilsExecError as msg:
# --> 386                 raise CompileError(msg)
#     387
#     388         return objects
#
# ImportError: Building module inferencer failed: ["distutils.errors.CompileError: command 'C:\\\\Program Files (x86)\\\\Microsoft Visual Studio 14.0\\\\VC\\\\BIN\\\\x86_amd64\\\\cl.exe' failed with exit status 2\n"]

# %%
from inferencer import IForest, LeafComputer, Blender, IForestBlender
# Out:
# warning: C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Includes\libcpp\algorithm.pxd:7:40: Function signature does not match previous declaration
# warning: C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Includes\libcpp\algorithm.pxd:11:38: Function signature does not match previous declaration
# warning: C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Includes\libcpp\algorithm.pxd:15:38: Function signature does not match previous declaration
# warning: C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Includes\libcpp\algorithm.pxd:19:36: Function signature does not match previous declaration
# warning: C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Includes\libcpp\algorithm.pxd:23:28: Function signature does not match previous declaration
# warning: C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Includes\libcpp\algorithm.pxd:27:38: Function signature does not match previous declaration
# warning: C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Includes\libcpp\algorithm.pxd:31:33: Function signature does not match previous declaration
# warning: C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Includes\libcpp\algorithm.pxd:34:32: Function signature does not match previous declaration
# warning: C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Includes\libcpp\algorithm.pxd:37:33: Function signature does not match previous declaration
# warning: C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Includes\libcpp\algorithm.pxd:40:33: Function signature does not match previous declaration
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# from .utility cimport pair
#
# cdef extern from "<unordered_map>" namespace "std" nogil:
#     cdef cppclass unordered_map[T, U]:
#         ctypedef T key_type
#        ^
# ------------------------------------------------------------
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Includes\libcpp\unordered_map.pxd:5:8: Expected an identifier, found 'ctypedef'
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# from .utility cimport pair
#
# cdef extern from "<unordered_map>" namespace "std" nogil:
#     cdef cppclass unordered_map[T, U]:
#         ctypedef T key_type
#                   ^
# ------------------------------------------------------------
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Includes\libcpp\unordered_map.pxd:5:19: Syntax error in C variable declaration
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# cimport numpy as np
#
# from libc.math cimport log, abs, exp, pow
# from cython.operator cimport dereference as deref, preincrement as inc
# from libcpp.algorithm cimport sort as stdsort
# from libcpp.unordered_map cimport unordered_map
# ^
# ------------------------------------------------------------
#
# inferencer.pyx:13:0: 'libcpp\unordered_map\unordered_map.pxd' not found
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# cdef extern from "<vector>" namespace "std" nogil:
#     cdef cppclass vector[T,ALLOCATOR=*]:
#         ctypedef T value_type
#        ^
# ------------------------------------------------------------
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Includes\libcpp\vector.pxd:3:8: Expected an identifier, found 'ctypedef'
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# cdef extern from "<vector>" namespace "std" nogil:
#     cdef cppclass vector[T,ALLOCATOR=*]:
#         ctypedef T value_type
#                   ^
# ------------------------------------------------------------
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Includes\libcpp\vector.pxd:3:19: Syntax error in C variable declaration
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# from libc.math cimport log, abs, exp, pow
# from cython.operator cimport dereference as deref, preincrement as inc
# from libcpp.algorithm cimport sort as stdsort
# from libcpp.unordered_map cimport unordered_map
# from libcpp cimport bool
# from libcpp.vector cimport vector
# ^
# ------------------------------------------------------------
#
# inferencer.pyx:15:0: 'libcpp\vector\vector.pxd' not found
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# cdef extern from "<utility>" namespace "std" nogil:
#     cdef cppclass pair[T, U]:
#         ctypedef T first_type
#        ^
# ------------------------------------------------------------
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Includes\libcpp\utility.pxd:3:8: Expected an identifier, found 'ctypedef'
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# cdef extern from "<utility>" namespace "std" nogil:
#     cdef cppclass pair[T, U]:
#         ctypedef T first_type
#                   ^
# ------------------------------------------------------------
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Includes\libcpp\utility.pxd:3:19: Syntax error in C variable declaration
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# from .utility cimport pair
# ^
# ------------------------------------------------------------
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Includes\libcpp\pair.pxd:1:0: 'libcpp\utility\pair.pxd' not found
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# from libcpp.unordered_map cimport unordered_map
# from libcpp cimport bool
# from libcpp.vector cimport vector
# from libcpp.pair cimport pair
#
# ctypedef pair[int,float] DP
#         ^
# ------------------------------------------------------------
#
# inferencer.pyx:18:9: 'pair' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# from libcpp cimport bool
# from libcpp.vector cimport vector
# from libcpp.pair cimport pair
#
# ctypedef pair[int,float] DP
# ctypedef vector[DP] SR
#         ^
# ------------------------------------------------------------
#
# inferencer.pyx:19:9: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# from libcpp.vector cimport vector
# from libcpp.pair cimport pair
#
# ctypedef pair[int,float] DP
# ctypedef vector[DP] SR
# ctypedef vector[SR] CSR
#         ^
# ------------------------------------------------------------
#
# inferencer.pyx:20:9: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# from libcpp.pair cimport pair
#
# ctypedef pair[int,float] DP
# ctypedef vector[DP] SR
# ctypedef vector[SR] CSR
# ctypedef vector[vector[float]] DENSE
#         ^
# ------------------------------------------------------------
#
# inferencer.pyx:21:9: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         p.second = data[i]
#         sparse.push_back(p)
#
#     return sparse
#
# cdef SR sparse_sr_mean(const vector[SR*] probs, SR& averaged):
#                             ^
# ------------------------------------------------------------
#
# inferencer.pyx:80:29: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#             for i in range(0, len(values)):
#                 row.push_back(values[i])
#
#             dense.push_back(row)
#
# cdef load_dense_int(str fname, vector[vector[int]]& dense):
#                               ^
# ------------------------------------------------------------
#
# inferencer.pyx:152:31: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         self._predict(sr, payload)
#         return sr_to_sparse(payload, self.n_labels)
#
# cdef class ITree:
#     cdef int rootIdx
#     cdef vector[vector[int]] tree
#         ^
# ------------------------------------------------------------
#
# inferencer.pyx:274:9: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     cdef vector[vector[int]] tree
#     cdef CSR payloads
#
#     cdef CSR W
#
#     cdef vector[float] bias
#         ^
# ------------------------------------------------------------
#
# inferencer.pyx:279:9: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
#     cdef SR* predict_payload(self, const SR& sr):
#         cdef int idx = self.predict_sr(sr)
#         return &self.payloads[idx]
#
#     cdef inline int index(self, const vector[int]& node):
#                                      ^
# ------------------------------------------------------------
#
# inferencer.pyx:305:38: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         return &self.payloads[idx]
#
#     cdef inline int index(self, const vector[int]& node):
#         return node[0]
#
#     cdef inline int left(self, const vector[int]& node):
#                                     ^
# ------------------------------------------------------------
#
# inferencer.pyx:308:37: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         return node[0]
#
#     cdef inline int left(self, const vector[int]& node):
#         return node[1]
#
#     cdef inline int right(self, const vector[int]& node):
#                                      ^
# ------------------------------------------------------------
#
# inferencer.pyx:311:38: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         return node[1]
#
#     cdef inline int right(self, const vector[int]& node):
#         return node[2]
#
#     cdef inline bool is_leaf(self, const vector[int]& node):
#                                         ^
# ------------------------------------------------------------
#
# inferencer.pyx:314:41: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#             node = self.tree[nIndex]
#
#         return self.index(node)
#
# cdef class LeafComputer:
#     cdef vector[float] norms
#         ^
# ------------------------------------------------------------
#
# inferencer.pyx:338:9: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
#         return self.index(node)
#
# cdef class LeafComputer:
#     cdef vector[float] norms
#     cdef vector[float] radii
#         ^
# ------------------------------------------------------------
#
# inferencer.pyx:339:9: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         self.radii.swap(tmp2[0])
#
#         # Load means
#         load_sparse(p + '.means', self.means)
#
#     cdef void predict(self, const SR& X, const vector[int] ys, const float gamma, SR& out):
#                                               ^
# ------------------------------------------------------------
#
# inferencer.pyx:358:47: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#             k = exp(gamma  * (dist - self.radii[yi]))
#             p.first = i
#             p.second = 1. / (1. + k)
#             out.push_back(p)
#
# cdef void norm(const vector[float]& norms, const SR& X, SR& normed):
#                     ^
# ------------------------------------------------------------
#
# inferencer.pyx:378:21: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     cdef np.ndarray[np.int32_t] c = np.zeros(count, dtype=np.int32)
#     cdef np.ndarray[np.float32_t] d = np.zeros(count, dtype=np.float32)
#
#     cdef int [:] cv = c
#     cdef float [:] dv = d
#     cdef pair[int,float] p
#         ^
# ------------------------------------------------------------
#
# inferencer.pyx:32:9: 'pair' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
#     return tally + bias
#
# cdef SR convert_to_sr(const int [:] indices, const float [:] data, const int size):
#     cdef SR sparse
#     cdef pair[int,float] p
#         ^
# ------------------------------------------------------------
#
# inferencer.pyx:69:9: 'pair' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         sparse.push_back(p)
#
#     return sparse
#
# cdef SR sparse_sr_mean(const vector[SR*] probs, SR& averaged):
#     cdef unordered_map[int,float] summer
#         ^
# ------------------------------------------------------------
#
# inferencer.pyx:81:9: 'unordered_map' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         sr = probs[i]
#         for k in range(deref(sr).size()):
#             summer[deref(sr)[k].first] += deref(sr)[k].second
#
#     # Copy it into a new vector, averaging the values
#     cdef unordered_map[int,float].iterator b = summer.begin()
#         ^
# ------------------------------------------------------------
#
# inferencer.pyx:92:9: 'unordered_map' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         for k in range(deref(sr).size()):
#             summer[deref(sr)[k].first] += deref(sr)[k].second
#
#     # Copy it into a new vector, averaging the values
#     cdef unordered_map[int,float].iterator b = summer.begin()
#     cdef unordered_map[int,float].iterator e = summer.end()
#         ^
# ------------------------------------------------------------
#
# inferencer.pyx:93:9: 'unordered_map' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#                 row.push_back(p)
#
#             csr.push_back(row)
#
# cdef load_dense_f32(str fname, DENSE& dense):
#     cdef vector[float] row
#         ^
# ------------------------------------------------------------
#
# inferencer.pyx:136:9: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#                 row.push_back(values[i])
#
#             dense.push_back(row)
#
# cdef load_dense_int(str fname, vector[vector[int]]& dense):
#     cdef vector[int] row
#         ^
# ------------------------------------------------------------
#
# inferencer.pyx:153:9: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         # If blend == 1.0, we're done
#         if blend == 1.0:
#             return sr_to_sparse(tree_probs, self.forest.n_labels)
#
#         cdef SR leaf_probs
#         cdef vector[int] labels
#             ^
# ------------------------------------------------------------
#
# inferencer.pyx:193:13: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
#     cdef SR* _predict_tree(self, const SR& sr, ITree t):
#         return t.predict_payload(sr)
#
#     cdef void _predict(self, const SR& sr, SR& payload):
#         cdef vector[SR*] prob_set
#             ^
# ------------------------------------------------------------
#
# inferencer.pyx:257:13: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     cdef inline bool is_leaf(self, const vector[int]& node):
#         return node[3] == 1
#
#     cdef int predict_sr(self, const SR& data):
#         cdef unsigned int index, nIndex
#         cdef vector[int] node
#             ^
# ------------------------------------------------------------
#
# inferencer.pyx:319:13: 'vector' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         val = deref(b)
#         val.second = val.second / probs.size()
#         averaged.push_back(val)
#         inc(b)
#
#     stdsort(averaged.begin(), averaged.end())
#           ^
# ------------------------------------------------------------
#
# inferencer.pyx:102:11: Call with wrong number of arguments (expected 3, got 2)
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         while True:
#             values = read_row(f, 'If')
#             if values is None:
#                 break
#
#             row = vector[DP]()
#                           ^
# ------------------------------------------------------------
#
# inferencer.pyx:127:27: 'DP' is not a constant, variable or function identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     cdef void _predict(self, const SR& sr, SR& payload):
#         cdef vector[SR*] prob_set
#         cdef SR* res
#         for t in self.trees:
#             res = self._predict_tree(sr, t)
#             prob_set.push_back(res)
#                                  ^
# ------------------------------------------------------------
#
# inferencer.pyx:261:34: Cannot convert 'SR *' to Python object
# ---------------------------------------------------------------------------
# DistutilsExecError                        Traceback (most recent call last)
# C:\Users\kaoyuant\Anaconda3\lib\distutils\_msvccompiler.py in compile(self, sources, output_dir, macros, include_dirs, debug, extra_preargs, extra_postargs, depends)
#     383             try:
# --> 384                 self.spawn(args)
#     385             except DistutilsExecError as msg:
#
# C:\Users\kaoyuant\Anaconda3\lib\distutils\_msvccompiler.py in spawn(self, cmd)
#     502             os.environ['path'] = self._paths
# --> 503             return super().spawn(cmd)
#     504         finally:
#
# C:\Users\kaoyuant\Anaconda3\lib\distutils\ccompiler.py in spawn(self, cmd)
#     908     def spawn(self, cmd):
# --> 909         spawn(cmd, dry_run=self.dry_run)
#     910
#
# C:\Users\kaoyuant\Anaconda3\lib\distutils\spawn.py in spawn(cmd, search_path, verbose, dry_run)
#      37     elif os.name == 'nt':
# ---> 38         _spawn_nt(cmd, search_path, dry_run=dry_run)
#      39     else:
#
# C:\Users\kaoyuant\Anaconda3\lib\distutils\spawn.py in _spawn_nt(cmd, search_path, verbose, dry_run)
#      80             raise DistutilsExecError(
# ---> 81                   "command %r failed with exit status %d" % (cmd, rc))
#      82
#
# DistutilsExecError: command 'C:\\Program Files (x86)\\Microsoft Visual Studio 14.0\\VC\\BIN\\x86_amd64\\cl.exe' failed with exit status 2
#
# During handling of the above exception, another exception occurred:
#
# CompileError                              Traceback (most recent call last)
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\pyximport\pyximport.py in load_module(name, pyxfilename, pyxbuild_dir, is_package, build_inplace, language_level, so_path)
#     215                                    inplace=build_inplace, language_level=language_level)
# --> 216         mod = imp.load_dynamic(name, so_path)
#     217         if is_package and not hasattr(mod, '__path__'):
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\pyximport\pyximport.py in build_module(name, pyxfilename, pyxbuild_dir, inplace, language_level)
#     191                                   reload_support=pyxargs.reload_support)
# --> 192     assert os.path.exists(so_path), "Cannot find: %s" % so_path
#     193
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\pyximport\pyxbuild.py in pyx_to_dll(filename, ext, force_rebuild, build_in_temp, pyxbuild_dir, setup_args, reload_support, inplace)
#     101         obj_build_ext = dist.get_command_obj("build_ext")
# --> 102         dist.run_commands()
#     103         so_path = obj_build_ext.get_outputs()[0]
#
# C:\Users\kaoyuant\Anaconda3\lib\distutils\dist.py in run_commands(self)
#     954         for cmd in self.commands:
# --> 955             self.run_command(cmd)
#     956
#
# C:\Users\kaoyuant\Anaconda3\lib\distutils\dist.py in run_command(self, command)
#     973         cmd_obj.ensure_finalized()
# --> 974         cmd_obj.run()
#     975         self.have_run[command] = 1
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Distutils\build_ext.py in run(self)
#
# C:\Users\kaoyuant\Anaconda3\lib\distutils\command\build_ext.py in run(self)
#     337         # Now actually compile and link everything.
# --> 338         self.build_extensions()
#     339
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Distutils\build_ext.py in build_extensions(self)
#
# C:\Users\kaoyuant\Anaconda3\lib\distutils\command\build_ext.py in build_extension(self, ext)
#     531                                          extra_postargs=extra_args,
# --> 532                                          depends=ext.depends)
#     533
#
# C:\Users\kaoyuant\Anaconda3\lib\distutils\_msvccompiler.py in compile(self, sources, output_dir, macros, include_dirs, debug, extra_preargs, extra_postargs, depends)
#     385             except DistutilsExecError as msg:
# --> 386                 raise CompileError(msg)
#     387
#
# CompileError: command 'C:\\Program Files (x86)\\Microsoft Visual Studio 14.0\\VC\\BIN\\x86_amd64\\cl.exe' failed with exit status 2
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-13-af7be4df5e82> in <module>()
# ----> 1 from inferencer import IForest, LeafComputer, Blender, IForestBlender
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\pyximport\pyximport.py in load_module(self, fullname)
#     443             "invalid module, expected %s, got %s" % (
#     444             self.fullname, fullname))
# --> 445         if self.init_path:
#     446             # package
#     447             #print "PACKAGE", fullname
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\pyximport\pyximport.py in load_module(name, pyxfilename, pyxbuild_dir, is_package, build_inplace, language_level, so_path)
#     230             if sys.version_info[0] >= 3:
#     231                 raise exc.with_traceback(tb)
# --> 232             else:
#     233                 exec("raise exc, None, tb", {'exc': exc, 'tb': tb})
#     234     return mod
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\pyximport\pyximport.py in load_module(name, pyxfilename, pyxbuild_dir, is_package, build_inplace, language_level, so_path)
#     214             so_path = build_module(module_name, pyxfilename, pyxbuild_dir,
#     215                                    inplace=build_inplace, language_level=language_level)
# --> 216         mod = imp.load_dynamic(name, so_path)
#     217         if is_package and not hasattr(mod, '__path__'):
#     218             mod.__path__ = [os.path.dirname(so_path)]
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\pyximport\pyximport.py in build_module(name, pyxfilename, pyxbuild_dir, inplace, language_level)
#     190                                   inplace=inplace,
#     191                                   reload_support=pyxargs.reload_support)
# --> 192     assert os.path.exists(so_path), "Cannot find: %s" % so_path
#     193
#     194     junkpath = os.path.join(os.path.dirname(so_path), name+"_*") #very dangerous with --inplace ? yes, indeed, trying to eat my files ;)
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\pyximport\pyxbuild.py in pyx_to_dll(filename, ext, force_rebuild, build_in_temp, pyxbuild_dir, setup_args, reload_support, inplace)
#     100     try:
#     101         obj_build_ext = dist.get_command_obj("build_ext")
# --> 102         dist.run_commands()
#     103         so_path = obj_build_ext.get_outputs()[0]
#     104         if obj_build_ext.inplace:
#
# C:\Users\kaoyuant\Anaconda3\lib\distutils\dist.py in run_commands(self)
#     953         """
#     954         for cmd in self.commands:
# --> 955             self.run_command(cmd)
#     956
#     957     # -- Methods that operate on its Commands --------------------------
#
# C:\Users\kaoyuant\Anaconda3\lib\distutils\dist.py in run_command(self, command)
#     972         cmd_obj = self.get_command_obj(command)
#     973         cmd_obj.ensure_finalized()
# --> 974         cmd_obj.run()
#     975         self.have_run[command] = 1
#     976
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Distutils\build_ext.py in run(self)
#
# C:\Users\kaoyuant\Anaconda3\lib\distutils\command\build_ext.py in run(self)
#     336
#     337         # Now actually compile and link everything.
# --> 338         self.build_extensions()
#     339
#     340     def check_extensions_list(self, extensions):
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\Cython\Distutils\build_ext.py in build_extensions(self)
#
# C:\Users\kaoyuant\Anaconda3\lib\distutils\command\build_ext.py in build_extension(self, ext)
#     530                                          debug=self.debug,
#     531                                          extra_postargs=extra_args,
# --> 532                                          depends=ext.depends)
#     533
#     534         # XXX outdated variable, kept here in case third-part code
#
# C:\Users\kaoyuant\Anaconda3\lib\distutils\_msvccompiler.py in compile(self, sources, output_dir, macros, include_dirs, debug, extra_preargs, extra_postargs, depends)
#     384                 self.spawn(args)
#     385             except DistutilsExecError as msg:
# --> 386                 raise CompileError(msg)
#     387
#     388         return objects
#
# ImportError: Building module inferencer failed: ["distutils.errors.CompileError: command 'C:\\\\Program Files (x86)\\\\Microsoft Visual Studio 14.0\\\\VC\\\\BIN\\\\x86_amd64\\\\cl.exe' failed with exit status 2\n"]

# %%
from sklearn.ensemble import RandomForestClassifier
import time

#y_train=y_train.todense()
classifier = RandomForestClassifier()
start=time.time()
classifier.fit(x_train, y_train)
#y_hat = classifier.predict(x_test)
print(time.time()-start)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-8ac65aecf024> in <module>()
#       5 classifier = RandomForestClassifier()
#       6 start=time.time()
# ----> 7 classifier.fit(x_train, y_train)
#       8 #y_hat = classifier.predict(x_test)
#       9 print(time.time()-start)
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     271         self.n_outputs_ = y.shape[1]
#     272
# --> 273         y, expanded_class_weight = self._validate_y_class_weight(y)
#     274
#     275         if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in _validate_y_class_weight(self, y)
#     469
#     470     def _validate_y_class_weight(self, y):
# --> 471         check_classification_targets(y)
#     472
#     473         y = np.copy(y)
#
# C:\Users\kaoyuant\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
#     170     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     171                       'multilabel-indicator', 'multilabel-sequences']:
# --> 172         raise ValueError("Unknown label type: %r" % y_type)
#     173
#     174
#
# ValueError: Unknown label type: 'unknown'

# %%
y_train.shape
# Out:
# (623847, 2456)

# %%
x_train.shape
# Out:
# (623847, 47236)

# %%
type(y_train)
# Out:
# scipy.sparse.lil.lil_matrix

# %%
type(x_train)
# Out:
# scipy.sparse.lil.lil_matrix

# %%
import pyximport

# %%
cimport cython
cimport numpy as np
# Out:
#   File "<ipython-input-20-1f4a457f2f4b>", line 1
#     cimport cython
#                  ^
# SyntaxError: invalid syntax
