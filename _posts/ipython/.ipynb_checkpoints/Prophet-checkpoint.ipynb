# %% [markdown]
# ## Time Series Forecasting with Prophet
#
# ### Introduction
#
# Time series forecasting is used in multiple business domains, such as pricing, capacity planning, inventory management, etc. Forecasting with techniques such as ARIMA requires the user to correctly determine and validate the model parameters (p,q,d). This is a multistep process that requires the user to interpret the ACF and PCF plots correctly. Using the wrong model can easily lead to erroneous results.
#
# [Prophet](https://facebook.github.io/prophet/docs/) is an open source time series forecasting library made available by Facebook's Core Data Science team. It is available both in Python and R, and it's syntax follow's [Scikit-learn's](http://scikit-learn.org/) `train` and `predict` model.
#
# Prophet is built for [business cases](https://research.fb.com/prophet-forecasting-at-scale) typically encounted at Facebook, but which are also encountered in other businesses:
#
# 1. Hourly, Daily or Weekly data with sufficient historical data
# 2. Multiple Seasonality patterns related to human behaviour (day of week, seasons)
# 3. Important holidays that are irregularly spaced (Thanksgiving, Chinese New Year, etc.)
# 4. Reasonable amount of missing data
# 5. Historical trend changes
# 6. Non linear growth trends with saturation (capacity limit, etc.)
#
# The goal of Prophet is to product high quality forecasts for decision making out of the box without requiring the user to have expert time series forecasting knowledge. The user can intuitively intervene during the model building process by

# %% [markdown]
# ### Stan
#
# Prophet uses [Stan]() as its

# %% [markdown]
# ### Data
#
# According to Facebook, Prophet is able to give accurate forecasting results with it's default settings, no tuning required. Let's test out Prophet using two different datasets:
# 1. Weather
# 2. Store demand

# %% [markdown]
# ### Parameters

# %% [markdown]
# ### Breakpoints

# %% [markdown]
# ### Validation

# %% [markdown]
# ### Uncertainty Interval

# %% [markdown]
# ### Metrics

# %%
import pandas as pd
from fbprophet import Prophet

# %%
df = pd.read_csv('D:/example_wp_log_peyton_manning.csv')

# %%
m = Prophet()
m.fit(df)
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods=365)
forecast = m.predict(future)

# %%
fig1 = m.plot(forecast)

# %%
fig2 = m.plot_components(forecast)

# %%
from fbprophet.plot import add_changepoints_to_plot
fig = m.plot(forecast)
a = add_changepoints_to_plot(fig.gca(), m, forecast)

# %%
m = Prophet(changepoint_prior_scale=0.5)
forecast = m.fit(df).predict(future)
fig = m.plot(forecast)
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
m = Prophet(changepoint_prior_scale=0.001)
forecast = m.fit(df).predict(future)
fig = m.plot(forecast)
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
m = Prophet(changepoints=['2014-01-01'])
forecast = m.fit(df).predict(future)
fig = m.plot(forecast)
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
playoffs = pd.DataFrame({
  'holiday': 'playoff',
  'ds': pd.to_datetime(['2008-01-13', '2009-01-03', '2010-01-16',
                        '2010-01-24', '2010-02-07', '2011-01-08',
                        '2013-01-12', '2014-01-12', '2014-01-19',
                        '2014-02-02', '2015-01-11', '2016-01-17',
                        '2016-01-24', '2016-02-07']),
  'lower_window': 0,
  'upper_window': 1,
})
superbowls = pd.DataFrame({
  'holiday': 'superbowl',
  'ds': pd.to_datetime(['2010-02-07', '2014-02-02', '2016-02-07']),
  'lower_window': 0,
  'upper_window': 1,
})
holidays = pd.concat((playoffs, superbowls))

# %%
m = Prophet(holidays=holidays)
forecast = m.fit(df).predict(future)
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
fig = m.plot_components(forecast)

# %%
from fbprophet.plot import plot_yearly
m = Prophet().fit(df)
a = plot_yearly(m)
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
from fbprophet.plot import plot_yearly
m = Prophet(yearly_seasonality=20).fit(df)
a = plot_yearly(m)
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
m = Prophet(weekly_seasonality=False)
m.add_seasonality(name='monthly', period=30.5, fourier_order=5)
forecast = m.fit(df).predict(future)
fig = m.plot_components(forecast)
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
m = Prophet(holidays=holidays, holidays_prior_scale=0.05).fit(df)
forecast = m.predict(future)
forecast[(forecast['playoff'] + forecast['superbowl']).abs() > 0][
    ['ds', 'playoff', 'superbowl']][-10:]
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#              ds   playoff  superbowl
# 2190 2014-02-02  1.206462   0.962911
# 2191 2014-02-03  1.852808   0.992123
# 2532 2015-01-11  1.206462   0.000000
# 2533 2015-01-12  1.852808   0.000000
# 2901 2016-01-17  1.206462   0.000000
# 2902 2016-01-18  1.852808   0.000000
# 2908 2016-01-24  1.206462   0.000000
# 2909 2016-01-25  1.852808   0.000000
# 2922 2016-02-07  1.206462   0.962911
# 2923 2016-02-08  1.852808   0.992123

# %%
m = Prophet()
m.add_seasonality(
    name='weekly', period=7, fourier_order=3, prior_scale=0.1)

# %%
def nfl_sunday(ds):
    date = pd.to_datetime(ds)
    if date.weekday() == 6 and (date.month > 8 or date.month < 2):
        return 1
    else:
        return 0
df['nfl_sunday'] = df['ds'].apply(nfl_sunday)

m = Prophet()
m.add_regressor('nfl_sunday')
m.fit(df)

future['nfl_sunday'] = future['ds'].apply(nfl_sunday)

forecast = m.predict(future)
fig = m.plot_components(forecast)
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
m = Prophet(mcmc_samples=300)
forecast = m.fit(df).predict(future)
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\david\AppData\Local\Continuum\Anaconda3\lib\site-packages\pystan\misc.py:455: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   if "chain_id" in inspect.getargspec(init).args:
# WARNING:pystan:n_eff / iter for parameter beta_m[1] is nan!
# WARNING:pystan:n_eff / iter for parameter beta_m[2] is nan!
# WARNING:pystan:n_eff / iter for parameter beta_m[3] is nan!
# WARNING:pystan:n_eff / iter for parameter beta_m[4] is nan!
# WARNING:pystan:n_eff / iter for parameter beta_m[5] is nan!
# WARNING:pystan:n_eff / iter for parameter beta_m[6] is nan!
# WARNING:pystan:n_eff / iter for parameter beta_m[7] is nan!
# WARNING:pystan:n_eff / iter for parameter beta_m[8] is nan!
# WARNING:pystan:n_eff / iter for parameter beta_m[9] is nan!
# WARNING:pystan:n_eff / iter for parameter beta_m[10] is nan!
# WARNING:pystan:n_eff / iter for parameter beta_m[11] is nan!
# WARNING:pystan:n_eff / iter for parameter beta_m[12] is nan!
# WARNING:pystan:n_eff / iter for parameter beta_m[13] is nan!
# WARNING:pystan:n_eff / iter for parameter beta_m[14] is nan!
# WARNING:pystan:n_eff / iter for parameter beta_m[15] is nan!
# WARNING:pystan:n_eff / iter for parameter beta_m[16] is nan!
# WARNING:pystan:n_eff / iter for parameter beta_m[17] is nan!
# WARNING:pystan:n_eff / iter for parameter beta_m[18] is nan!
# WARNING:pystan:n_eff / iter for parameter beta_m[19] is nan!
# WARNING:pystan:n_eff / iter for parameter beta_m[20] is nan!
# WARNING:pystan:n_eff / iter for parameter beta_m[21] is nan!
# WARNING:pystan:n_eff / iter for parameter beta_m[22] is nan!
# WARNING:pystan:n_eff / iter for parameter beta_m[23] is nan!
# WARNING:pystan:n_eff / iter for parameter beta_m[24] is nan!
# WARNING:pystan:n_eff / iter for parameter beta_m[25] is nan!
# WARNING:pystan:n_eff / iter for parameter beta_m[26] is nan!
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat for parameter beta_m[1] is nan!
# WARNING:pystan:Rhat for parameter beta_m[2] is nan!
# WARNING:pystan:Rhat for parameter beta_m[3] is nan!
# WARNING:pystan:Rhat for parameter beta_m[4] is nan!
# WARNING:pystan:Rhat for parameter beta_m[5] is nan!
# WARNING:pystan:Rhat for parameter beta_m[6] is nan!
# WARNING:pystan:Rhat for parameter beta_m[7] is nan!
# WARNING:pystan:Rhat for parameter beta_m[8] is nan!
# WARNING:pystan:Rhat for parameter beta_m[9] is nan!
# WARNING:pystan:Rhat for parameter beta_m[10] is nan!
# WARNING:pystan:Rhat for parameter beta_m[11] is nan!
# WARNING:pystan:Rhat for parameter beta_m[12] is nan!
# WARNING:pystan:Rhat for parameter beta_m[13] is nan!
# WARNING:pystan:Rhat for parameter beta_m[14] is nan!
# WARNING:pystan:Rhat for parameter beta_m[15] is nan!
# WARNING:pystan:Rhat for parameter beta_m[16] is nan!
# WARNING:pystan:Rhat for parameter beta_m[17] is nan!
# WARNING:pystan:Rhat for parameter beta_m[18] is nan!
# WARNING:pystan:Rhat for parameter beta_m[19] is nan!
# WARNING:pystan:Rhat for parameter beta_m[20] is nan!
# WARNING:pystan:Rhat for parameter beta_m[21] is nan!
# WARNING:pystan:Rhat for parameter beta_m[22] is nan!
# WARNING:pystan:Rhat for parameter beta_m[23] is nan!
# WARNING:pystan:Rhat for parameter beta_m[24] is nan!
# WARNING:pystan:Rhat for parameter beta_m[25] is nan!
# WARNING:pystan:Rhat for parameter beta_m[26] is nan!
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:535 of 600 iterations saturated the maximum tree depth of 10 (89.16666666666667%)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation

# %%
fig = m.plot_components(forecast)
